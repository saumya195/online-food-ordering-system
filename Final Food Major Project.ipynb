# %%
def msg(payload):
    import requests
    url = "https://www.fast2sms.com/dev/bulk"
    headers = {
    'authorization': "m4ZXAwltQrbEKR3jd2hIOnUF9gp6qP1CsLf70zH5u8NTcvxaDJ9rstiGh8muJzV6CyDAp5k3F0Zcgx7W",
    'Content-Type': "application/x-www-form-urlencoded",
    'Cache-Control': "no-cache",
    }
    response = requests.request("POST", url, data=payload, headers=headers)
    print(response.text)
    

def rss(p):
    import turtle
    s = turtle.Turtle()
    s.backward(300)
    s.forward(300)
    s.left(90)
    s.forward(50)
    s.left(90)
    s.forward(50)
    s.left(90)
    s.forward(50)
    s.left(90)
    s.forward(50)
    s.left(90)
    s.forward(250)
    s.left(90)
    s.forward(50)
    s.left(90)
    s.forward(50)
    s.left(90)
    s.forward(50)
    s.left(90)
    s.forward(100)
    
    s.penup()
    s.right(90)
    s.forward(50)
    s.right(90)
    s.pendown()
    
    s.forward(200)
    s.left(90)
    s.forward(50)
    s.left(90)
    s.forward(50)
    s.left(90)
    s.forward(50)
    s.left(90)
    s.forward(150)
    s.left(90)
    s.forward(150)
    s.left(90)
    s.forward(50)
    s.left(90)
    s.forward(50)
    s.left(90)
    s.forward(50)
    s.left(90)
    s.forward(200)
    
    s.penup()
    s.right(90)
    s.forward(50)
    s.right(90)
    s.pendown()
    
    s.forward(100)
    s.left(90)
    s.forward(50)
    s.left(90)
    s.forward(50)
    s.left(90)
    s.forward(50)
    s.left(90)
    s.forward(250)
    s.left(90)
    s.forward(50)
    s.left(90)
    s.forward(50)
    s.left(90)
    s.forward(50)
    s.left(90)
    s.forward(50)
    s.left(90)
    s.forward(200)
    
    s.penup()
    s.right(90)
    s.forward(50)
    s.right(90)
    s.pendown()
    
    s.forward(100)
    s.left(90)
    s.forward(50)
    s.left(90)
    s.forward(50)
    s.left(90)
    s.forward(50)
    s.left(90)
    s.forward(150)
    s.left(90)
    s.forward(250)
    s.left(90)
    s.forward(50)
    s.left(90)
    s.forward(100)
    s.left(90)
    s.forward(50)
    s.left(90)
    s.forward(150)
    
    s.penup()
    s.backward(325)
    s.right(90)
    s.forward(40)
    s.left(90)
    s.pendown()

    s.circle(15)

    s.penup()
    s.left(90)
    s.forward(40)
    s.right(90)
    s.forward(235)
    s.left(90)
    s.forward(5)
    s.pendown()
    
    s.forward(40)
    s.backward(40)
    s.left(90)
    s.forward(20)
    s.right(90)
    s.forward(20)
    s.right(90)
    s.forward(20)
    s.left(135)
    s.forward(28.2)
    
    s.penup()
    s.left(135)
    s.forward(45)
    s.left(90)
    s.forward(10)
    s.right(90)
    s.forward(50)
    s.right(90)
    s.forward(175)
    s.left(90)
    s.forward(10)
    s.pendown()
    
    s.left(90)
    s.forward(10)
    s.backward(20)
    s.forward(10)
    s.right(90)
    s.forward(30)
    s.left(135)
    s.forward(14.1)
    s.backward(14.1)
    s.left(45)
    
    s.penup()
    s.forward(40)
    s.left(90)
    s.forward(25)
    s.left(90)
    s.forward(210)
    s.left(90)
    s.forward(10)
    s.pendown()
    
    s.forward(30)
    s.backward(10)
    s.right(135)
    s.forward(14.1)
    s.left(45)
    s.forward(10)
    s.left(45)
    s.forward(14.1)
    s.left(45)
    s.forward(10)
    
    s.penup()
    s.backward(40)
    s.right(90)
    s.backward(100)
    s.right(90)
    s.forward(65)
    s.pendown()
    
    s.forward(20)
    s.right(135)
    s.forward(21.2)
    s.left(135)
    s.forward(15)
    s.right(90)
    s.forward(15)
    s.right(90)
    s.forward(20)
    
    s.penup()
    s.forward(15)
    s.left(90)
    s.forward(110)
    s.left(90)
    s.forward(132.5)
    s.left(90)
    s.forward(10)
    s.pendown()
    
    s.forward(30)
    s.backward(15)
    s.left(90)
    s.forward(15)
    s.right(90)
    s.forward(15)
    
    s.penup()
    s.backward(40)
    s.right(90)
    s.forward(117.5)
    s.right(90)
    s.forward(60)
    s.pendown()

    s.right(90)
    s.forward(20)
    s.left(90)
    s.forward(15)
    s.left(90)
    s.forward(20)
    s.right(90)
    s.forward(15)
    s.right(90)
    s.forward(20)
    
    s.penup()
    s.right(90)
    s.forward(40)
    s.left(90)
    s.forward(180)
    s.left(90)
    s.forward(10)
    s.pendown()
    
    s.right(90)
    s.forward(20)
    s.left(90)
    s.forward(15)
    s.left(90)
    s.forward(20)
    s.right(90)
    s.forward(15)
    s.right(90)
    s.forward(20)
    s.right(90)
    s.forward(15)
    
    s.penup()
    s.forward(25)
    s.left(90)
    s.forward(15)
    s.left(90)
    s.forward(110)
    s.right(90)
    s.forward(62.5)
    s.pendown()
    
    s.forward(25)
    s.backward(25)
    s.left(60)
    s.forward(34.6)
    s.backward(34.6)
    s.left(120)
    
    s.penup()
    s.forward(12.5)
    s.left(90)
    s.forward(110)
    s.left(90)
    s.forward(200)
    s.right(90)
    s.pendown()
    
    s.forward(25)
    s.right(90)
    s.forward(200)
    s.left(90)
    if(p==1):
        for x in range(90):
            s.forward(0.436)
            s.right(1)
        s.left(90)
        s.forward(25)
        s.left(90)
        s.forward(25)
    elif(p==2):
        for x in range(90):
            s.forward(0.436)
            s.right(1)
        s.left(90)
        s.forward(225)
        s.left(90)
        s.forward(25)
    elif(p==3):
        for x in range(90):
            s.forward(0.436)
            s.right(1)
        s.left(90)
        s.forward(125)
        s.right(90)
        s.forward(25)
    elif(p==4):
        for x in range(180):
            s.forward(0.436)
            s.right(1)
        s.left(90)
        s.forward(125)
        s.left(90)
        s.forward(25)
    elif(p==5):
        for x in range(180):
            s.forward(0.436)
            s.right(1)
        s.left(90)
        s.forward(225)
        s.right(90)
        s.forward(25)
    elif(p==6):
        for x in range(180):
            s.forward(0.436)
            s.right(1)
        s.left(90)
        s.forward(25)
        s.right(90)
        s.forward(25)
    elif(p==7):
        for x in range(270):
            s.forward(0.436)
            s.right(1)
        s.left(90)
        s.forward(125)
        s.right(90)
        s.forward(25)

    turtle.done()


def compare():
    import matplotlib.pyplot as plt
    import pandas as pd
    import seaborn as sns
    v = pd.read_csv('Rest.csv')
    print("\n\n",v)
    plt.figure(figsize=(8,4))
    sns.barplot("Restaurant","Avg_Rating",data=v)
    plt.show()



print("                               Welcome to ONLINE FOOD ORDERING SYSTEM")
print("Enter \n1-Compare Restaurants\n2-Order Food")
scp = int(input("Enter your choice : "))
if(scp == 1):
    print("This table and graph tells you about different Restaurants and there Ratings : ")
    compare()
    sps = input("Would you like to place an order (y/n) ? :")
    if(sps == 'y'):
        scp = 2


if(scp == 2):    
    
    import re
    import csv
    import random
    import pandas as pd
    import time
    class Detail():
        valid_phone_no=False
        valid_email=False
        Name=input("Enter Name : ")
        phone_no=input("Enter Phone number : ")
        mail=input("Enter Email id : ")
    
        def processDetails(self):
            while not Detail.valid_phone_no:
                self.x=len(Detail.phone_no)
                if(self.x!=10):
                    Detail.phone_no=input("Enter correct phone number : ")
                else:
                    Detail.valid_phone_no= True
            while not Detail.valid_email:
                regex ='^\w+([\.-]?\w+)*@\w+([\.-]?\w+)*(\.\w{2,3})+$'
                if(re.search(regex,Detail.mail)):
                    Detail.valid_email= True
                else: 
                    Detail.mail=input("Enter valid Email : ")
    
        def otp(self): 
            self.S = random.randint(1000,10000)
            self.sp = str(self.S)
            self.A = []
            self.B = "sender_id=FSTSMS&message="
            self.C = "Your otp is "
            self.D = "&language=english&route=p&numbers="
            self.E = str(Detail.phone_no)
            self.A.append(self.B)
            self.A.append(self.C)
            self.A.append(self.sp)
            self.A.append(self.D)
            self.A.append(self.E)
            self.X = ''.join(self.A)
            msg(self.X)
        
        def check(self):
            self.processDetails()
            terminate = False
            Detail.otp(self)
            self.otps=int(input("Enter OTP : "))
            while not terminate:
                if(self.S!=self.otps):
                    print("Invalid OTP")
                    self.otps=int(input("Re-Enter OTP : "))
                else:
                    print("You are logged in Successfully!")
                    self.write_to_csv()
                    terminate = True
                
        
        def write_to_csv(self):
            with open('rv.csv','a',newline='') as f:
                thewriter=csv.writer(f)
                thewriter.writerow([Detail.Name,Detail.phone_no,Detail.mail])
            


            
            
    class restaurant():
        def process1(self):
            termin = False
            while not termin:
                print("\n\nHere are some available Restaurants :-\n1:TACO BELL \n2:SNACK POINT \n3:BERCOS \n4:WAFFLE STREET \n5:BURGER POINT \n6:CHINESE DELIGHT")
                choice=int(input("\nEnter the restaurant you would like to order food from : "))
                if(choice==1):
                    self.df = pd.DataFrame({'Food Item': ['Virgin Mojito', 'Crunchy taco with pinto bean', 'Soft taco with pinto bean', 'Crunchy taco with mexican paneer','Soft taco with mexican paneer','Vegstar wrap','Chickstar wrap','Chocodilla','Mineral water'],
                                'Price': [95, 80, 85, 90,75,145,149,100,30]},index=range(1,10))
                    print(self.df)
                if(choice==2):
                    self.df = pd.DataFrame({'Food Item': ['Paneer Tikka', 'Tandoori Chicken', 'Honey chilli potato', 'Chowmein','Paneer Momos','Italian soap','Cream Soup','Veg frankie','Chicken frankie','Mineral water'],
                                'Price': [295, 380, 180, 190,80,100,150,170,230,30]},index=range(1,11))
                    print(self.df)
                if(choice==3):
                    self.df = pd.DataFrame({'Food Item':['Crispy Chilli Potato','Vegetable Spring Rolls','Bercos Chilli Paneer','Cheese and Corn Rolls','Chilli garlic crispy vegetable'],
                                'Price':[295,300,360,370,345]},index=range(1,6))
                    print(self.df)
                if(choice==4):
                    self.df = pd.DataFrame({'Food Item': ['Honey Butter waffle','Brown Choco Delight waffle','Coffee Menace waffle', 'Snicker Boy waffle','Coco Almond waffle','Ferrero Rochers waffle','Oreo Craze waffle'],
                                'Price':[99,119,129,139,149,169,159]})
                    print(self.df)
                if(choice==5):
                    self.df= pd.DataFrame({'Food Item': ['Aloo Tikki Burger', 'Aloo tikki supreme burger', 'Aloo tikki cheese burger', 'Cheese overloaded veg burger','Chicken Burger','Chicken supreme burger','Paneer wrap','Chicken wrap','Chicken Nuggets','Potato Bites','Cold drink'],
                                'Price': [50, 80, 100, 120,180,199,149,170,150,160,35]},index=range(1,12))
                    print(self.df)
                if(choice==6):
                    self.df = pd.DataFrame({'Food Item':['Malai chaap','Chilli paneer noodles','Honey dip potatoes','French fries','White sauce pasta','red sauce pasta'],
                                'Price':[160,120,150,100,130,140]},index=range(1,7))
                    print(self.df)
                    
                pb = input("Switch Restaurant(y/n) ? : ")
                if(pb=='n'):
                    termin = True

    class cart(restaurant):
        count=0
        dict2={}
        item=[]
        terminate=False
        x=1
        def processcart(self,restaurant): 
        
            self.dictionary1 =restaurant.df.to_dict(orient="index")
        
            while not cart.terminate:
                cart.x=int(input("What you would like to order ? : "))
                self.item=self.dictionary1[cart.x]['Food Item']
                self.value=self.dictionary1[cart.x]['Price']
                cart.dict2[self.item]=self.value
                cart.count=cart.count+self.value
                cart.item.append(self.item)
                self.M=input("Would you like to add more items (y/n) ? : ")
                if(self.M=='y'):
                    cart.dict2.update({'item': 'value'})
                    del cart.dict2['item']
                if(self.M!='y'):
                    cart.terminate=True        
        
            print("You have ordered:")
            for k, v in cart.dict2.items():
                spb = 0
                for x in cart.item:
                    if(x==k):
                        spb = spb + 1
                print (k,'x',spb,'-->', v)
            print("Total amount"+"= Rs."+str(cart.count)) 
        
           
            sb = False
            while not sb:
                v=input("Place order (y/n) ? : ")
                if(v == 'y'):
                    sb = True
                if(v == 'n'):
                    print("\n1 - Add more items\n2 - Remove items\n3 - Cancel order")
                    sc = int(input("Enter your choice : "))
            
                    if(sc == 1):
                        st = False
                        while not st:
                            cart.x=int(input("What you would like to order ? : "))
                            self.item=self.dictionary1[cart.x]['Food Item']
                            self.value=self.dictionary1[cart.x]['Price']
                            cart.dict2[self.item]=self.value
                            cart.count=cart.count+self.value
                            cart.item.append(self.item)
                            self.M=input("Would you like to add more items (y/n) ? : ")
                            if(self.M=='y'):
                                cart.dict2.update({'item': 'value'})
                                del cart.dict2['item']
                            if(self.M!='y'):
                                st=True        
        
                        print("You have ordered:")
                        for k, v in cart.dict2.items():
                            spb = 0
                            for x in cart.item:
                                if(x==k):
                                    spb = spb + 1
                            print (k,'x',spb,'-->', v)
                        print("Total amount"+"= Rs."+str(cart.count))
                
            
                    if(sc == 2):
                        st = False
                        while not st:
                            cart.x=int(input("What you would like remove from your order ? : "))
                            self.item=self.dictionary1[cart.x]['Food Item']
                            self.value=self.dictionary1[cart.x]['Price']
                            SPB = 0
                            for x in cart.item:
                                if(x==self.item):
                                    SPB = SPB + 1
                            del cart.dict2[self.item]
                            for i in range(0,SPB):
                                cart.count=cart.count-self.value
                            self.M=input("Would you like to remove more items (y/n) ? : ")
                            if(self.M=='y'):
                                cart.dict2.update({'item': 'value'})
                                del cart.dict2['item']
                            if(self.M!='y'):
                                st=True        
        
    
                        print("You have ordered:")
                        for k, v in cart.dict2.items():
                            spb = 0
                            for x in cart.item:
                                if(x==k):
                                    spb = spb + 1
                            print (k,'x',spb,'-->', v)
                        print("Total amount"+"= Rs."+str(cart.count))
                
                    if(sc == 3):
                        print("Your order has been cancelled")
                        sb = True
            
            if(v == 'y'):
                hn=int(input("\nEnter your house number [1,2,3,4,5,6,7] : "))
                hs=input("Enter street address : ")
                print("\nORDER CONFIRMED ! PLEASE WAIT A WHILE\n")
                
                self.S = random.randint(100000,1000000)
                self.sp = str(self.S)
                self.A = []
                self.B = "sender_id=FSTSMS&message="
                self.C = "Your Order is confirmed. Your order id is #"
                self.D = "&language=english&route=p&numbers="
                self.E = str(Detail.phone_no)
                self.A.append(self.B)
                self.A.append(self.C)
                self.A.append(self.sp)
                self.A.append(self.D)
                self.A.append(self.E)
                self.X = ''.join(self.A)
                msg(self.X)
        
                for i in range(10, 0, -1):
                    print (i)
                    time.sleep(1)
                print ("\nOrder is on the way : ")
                rss(hn)
            
            
            
    class FEEDBACK():
        def feedback(self):
            print("\n\n1.\U0001F641")
            print("2.\U0001F610")
            print("3.\U0001F642")
            print("4.\U0001F603")
            print("5.\U0001F60D")
            c=int(input("How much would you rate the food ? : "))
            r=input("Rate the APP:(y/n)")
            if r=='n':
                print("THANK YOU FOR THE FEEDBACK..\nHAVE A NICE DAY!!")
            else:
                VR=[3,4,5,2,3,5,4,5,5,5]
                avg=0
                sum=0
                vr=int(input("Rating: 1-2-3-4-5\t"))
                with open('rating.csv','a',newline='') as f:
                    thewriter=csv.writer(f)
                    thewriter.writerow([vr])
                VR.append(vr)
                for i in VR:
                    sum=sum+i
                avg=sum/len(VR)
                print("The average rating is\t",int(avg))
                print("THANK YOU FOR THE FEEDBACK..\nHAVE A NICE DAY!!")
    
    
    
    obj1=Detail()
    obj1.check()
    obj2 = restaurant()
    obj2.process1()
    obj3 = cart()
    obj3.processcart(obj2)
    obj4=FEEDBACK()
    obj4.feedback()
